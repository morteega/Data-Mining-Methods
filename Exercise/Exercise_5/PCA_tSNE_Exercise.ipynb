# %% [markdown]
# ### Exercise 5 Notebook: Dimensionality Reduction with PCA & t-SNE on scRNA-seq Data
#
# #### About this Exercise
# This notebook focuses on two widely used dimensionality reduction techniques: **Principal Component Analysis (PCA)** and **t-Distributed Stochastic Neighbor Embedding (t-SNE)**. You will explore their application on **single-cell RNA sequencing (scRNA-seq)** data — a high-dimensional, real-world dataset from human blood cells (PBMCs).
#
# 💡 This is a valuable exercise for developing intuition about high-dimensional data and how dimensionality reduction methods help reveal structure in such datasets. These methods are also widely used in bioinformatics, computer vision, and any field dealing with many correlated features.
#
# 🚫 Please avoid using ChatGPT or other AI assistants to solve the tasks. Solving the problems yourself will help you truly understand the concepts and prepare better for the final exam.
#
# #### Context:
# In earlier sessions, you worked with pandas and sklearn on simpler datasets. Now you’ll experience working with **real-world high-dimensional biological data**. Each row in the dataset represents a single human immune cell, and each column represents the expression level of a gene. The cell types provided are actually resulted from a comperhensive analysis where marker genes where used to define cell type.
#
# Since visualizing thousands of dimensions is impossible, PCA and t-SNE allow us to project the data down to 2 dimensions while trying to preserve meaningful structure. This is especially useful in scRNA-seq to distinguish cell types or discover subpopulations.
#
# ### Goal:
# Your task is to:
# - Preprocess the count matrix and reduce the dimensionality of the dataset
# - Apply PCA and t-SNE, and visualize the results
# - Experiment with parameter settings
# - Reflect on the limitations and strengths of each method
#
# Follow the Jupyter notebook below and answer the tasks marked as ✅ **Task for Students**.

# %%
# Exercise: Visualizing High-Dimensional Data with PCA and t-SNE
import pandas as pd
import numpy as np
import scipy.io
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Set seed for reproducibility
random_seed = 42
np.random.seed(random_seed)

# %%
# read the annotated single Cell data
print("Loading data...")
df_pbmc= pd.read_pickle("pbmc3k_sparse.pkl")
df_pbmc.head(10)
# Out:
# Loading data...
#                   MIR1302-10  FAM138A  OR4F5  RP11-34P13.7  RP11-34P13.8  \
# AAACATACAACCAC-1           0        0      0             0             0
# AAACATTGAGCTAC-1           0        0      0             0             0
# AAACATTGATCAGC-1           0        0      0             0             0
# AAACCGTGCTTCCG-1           0        0      0             0             0
# AAACCGTGTATGCG-1           0        0      0             0             0
# AAACGCACTGGTAC-1           0        0      0             0             0
# AAACGCTGACCAGT-1           0        0      0             0             0
# AAACGCTGGTTCTT-1           0        0      0             0             0
# AAACGCTGTAGCCA-1           0        0      0             0             0
# AAACGCTGTTTCTG-1           0        0      0             0             0
#
#                   AL627309.1  RP11-34P13.14  RP11-34P13.9  AP006222.2  \
# AAACATACAACCAC-1           0              0             0           0
# AAACATTGAGCTAC-1           0              0             0           0
# AAACATTGATCAGC-1           0              0             0           0
# AAACCGTGCTTCCG-1           0              0             0           0
# AAACCGTGTATGCG-1           0              0             0           0
# AAACGCACTGGTAC-1           0              0             0           0
# AAACGCTGACCAGT-1           0              0             0           0
# AAACGCTGGTTCTT-1           0              0             0           0
# AAACGCTGTAGCCA-1           0              0             0           0
# AAACGCTGTTTCTG-1           0              0             0           0
#
#                   RP4-669L17.10  ...  AL354822.1  KIR2DL2  AL590523.1  \
# AAACATACAACCAC-1              0  ...           0        0           0
# AAACATTGAGCTAC-1              0  ...           0        0           0
# AAACATTGATCAGC-1              0  ...           0        0           0
# AAACCGTGCTTCCG-1              0  ...           0        0           0
# AAACCGTGTATGCG-1              0  ...           0        0           0
# AAACGCACTGGTAC-1              0  ...           0        0           0
# AAACGCTGACCAGT-1              0  ...           0        0           0
# AAACGCTGGTTCTT-1              0  ...           0        0           0
# AAACGCTGTAGCCA-1              0  ...           0        0           0
# AAACGCTGTTTCTG-1              0  ...           0        0           0
#
#                   CT476828.1  AC145205.1  BAGE5  CU459201.1  AC002321.2  \
# AAACATACAACCAC-1           0           0      0           0           0
# AAACATTGAGCTAC-1           0           0      0           0           0
# AAACATTGATCAGC-1           0           0      0           0           0
# AAACCGTGCTTCCG-1           0           0      0           0           0
# AAACCGTGTATGCG-1           0           0      0           0           0
# AAACGCACTGGTAC-1           0           0      0           0           0
# AAACGCTGACCAGT-1           0           0      0           0           0
# AAACGCTGGTTCTT-1           0           0      0           0           0
# AAACGCTGTAGCCA-1           0           0      0           0           0
# AAACGCTGTTTCTG-1           0           0      0           0           0
#
#                   AC002321.1          cell_type
# AAACATACAACCAC-1           0        CD4 T cells
# AAACATTGAGCTAC-1           0            B cells
# AAACATTGATCAGC-1           0        CD4 T cells
# AAACCGTGCTTCCG-1           0    CD14+ Monocytes
# AAACCGTGTATGCG-1           0           NK cells
# AAACGCACTGGTAC-1           0        CD8 T cells
# AAACGCTGACCAGT-1           0        CD8 T cells
# AAACGCTGGTTCTT-1           0        CD8 T cells
# AAACGCTGTAGCCA-1           0        CD4 T cells
# AAACGCTGTTTCTG-1           0  FCGR3A+ Monocytes
#
# [10 rows x 32644 columns]

# %% [markdown]
# 1. ✅ Task for students: Drop all genes where the sum of genes expression across all cells is less than 10, these genes are not useful for this analysis

# %%
# Exclude 'cell_type' column to work only with gene expression values
# Keep only genes (columns) where at least one cell has more than 10 total genes expression across cells
# Reattach the 'cell_type' column
cell_type=df_pbmc["cell_type"]
df_pbmc=df_pbmc.drop(columns="cell_type")
columns=[]
for column in df_pbmc.columns:
    if df_pbmc[column].sum()>10:
        columns.append(column)
df_pbmc=df_pbmc[columns]
df_pbmc=pd.concat([df_pbmc,cell_type], axis=1)
df_pbmc.head(10)


# your code here
# Out:
#                   LINC00115  NOC2L  HES4  ISG15  C1orf159  TNFRSF18  TNFRSF4  \
# AAACATACAACCAC-1          0      0     0      0         0         0        0
# AAACATTGAGCTAC-1          0      0     0      0         0       2.0        0
# AAACATTGATCAGC-1          0      0     0    1.0         0         0        0
# AAACCGTGCTTCCG-1          0      0     0    9.0         0         0        0
# AAACCGTGTATGCG-1          0      0     0      0         0         0        0
# AAACGCACTGGTAC-1          0      0     0    1.0         0         0        0
# AAACGCTGACCAGT-1          0      0     0      0         0         0        0
# AAACGCTGGTTCTT-1          0      0     0      0         0         0        0
# AAACGCTGTAGCCA-1          0      0     0      0         0         0      1.0
# AAACGCTGTTTCTG-1          0      0     0    3.0         0         0        0
#
#                   SDF4  B3GALT6  UBE2J2  ...  MT-CO3  MT-ND3  MT-ND4L  MT-ND4  \
# AAACATACAACCAC-1     0        0       0  ...     5.0     1.0        0    10.0
# AAACATTGAGCTAC-1     0        0       0  ...    15.0     2.0        0    33.0
# AAACATTGATCAGC-1   1.0        0       0  ...     4.0       0        0     3.0
# AAACCGTGCTTCCG-1     0        0       0  ...     4.0       0      1.0     3.0
# AAACCGTGTATGCG-1     0        0       0  ...     1.0       0        0       0
# AAACGCACTGGTAC-1     0        0       0  ...       0       0        0     4.0
# AAACGCTGACCAGT-1     0      1.0       0  ...    10.0     1.0        0     8.0
# AAACGCTGGTTCTT-1     0        0       0  ...    10.0       0        0    13.0
# AAACGCTGTAGCCA-1     0        0     1.0  ...     2.0     3.0        0     2.0
# AAACGCTGTTTCTG-1     0        0       0  ...     4.0       0        0     3.0
#
#                   MT-ND5  MT-ND6  MT-CYB  AC145212.1  AL592183.1  \
# AAACATACAACCAC-1     1.0       0     4.0           0           0
# AAACATTGAGCTAC-1     1.0       0     8.0           0         1.0
# AAACATTGATCAGC-1     2.0       0     4.0           0           0
# AAACCGTGCTTCCG-1     2.0       0     2.0           0           0
# AAACCGTGTATGCG-1     2.0       0     1.0           0           0
# AAACGCACTGGTAC-1       0       0     3.0           0           0
# AAACGCTGACCAGT-1     2.0       0     8.0           0           0
# AAACGCTGGTTCTT-1     1.0       0     7.0           0           0
# AAACGCTGTAGCCA-1       0       0     1.0           0           0
# AAACGCTGTTTCTG-1     1.0       0       0           0           0
#
#                           cell_type
# AAACATACAACCAC-1        CD4 T cells
# AAACATTGAGCTAC-1            B cells
# AAACATTGATCAGC-1        CD4 T cells
# AAACCGTGCTTCCG-1    CD14+ Monocytes
# AAACCGTGTATGCG-1           NK cells
# AAACGCACTGGTAC-1        CD8 T cells
# AAACGCTGACCAGT-1        CD8 T cells
# AAACGCTGGTTCTT-1        CD8 T cells
# AAACGCTGTAGCCA-1        CD4 T cells
# AAACGCTGTTTCTG-1  FCGR3A+ Monocytes
#
# [10 rows x 10987 columns]

# %% [markdown]
# 2. ✅ Task for students: Standardize the data with sklearn standard scaler (since we are not developing ML models, you can use the whole data set as input)

# %%
# Dont forget to Convert to numpy and drop cell type since we want only to scale genes expressions 
# your code here
standarizer=StandardScaler(with_mean=False)
cell_type=df_pbmc["cell_type"]

genes=df_pbmc.drop(columns="cell_type")
escaled_sparse=standarizer.fit_transform(genes)
scaled_array=escaled_sparse.toarray()
genes_escalated=pd.DataFrame(scaled_array,columns=genes.columns,index=genes.index)
df_pbmc=pd.concat([genes_escalated,cell_type],axis=1)

# %% [markdown]
# 3. ✅ Task for students:  Apply PCA to 50 Dimensions on the Standardize data

# %%
# your code here
pca=PCA(n_components=50)
cell_type=df_pbmc["cell_type"]
genes=df_pbmc.drop(columns="cell_type")
new_df_pbmc=pca.fit_transform(genes)
pca_colmuns=[]
for i in range(1,51):
    pca_colmuns.append(f"PC{i}")
df_pbmc=pd.DataFrame(new_df_pbmc,columns=pca_colmuns,index=genes.index)
df_pbmc["cell_type"]=cell_type

# %% [markdown]
# 4. ✅ Task for students:  Visualize the results with the top 2 PCs  using a scatter plot

# %%
# use sns.scatterplot
# your code here
sns.scatterplot(data=df_pbmc, x="PC1", y="PC2",hue="cell_type")
plt.title("Results with the top 2 PCs")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()

# %% [markdown]
# 5. ✅ Task for students: Apply t-SNE (after PCA to 50D), use default perplexity provided by sklearn TSNE function and two components

# %%
# use sklearn tSNE 
# your code here
tnse=TSNE(n_components=2, perplexity=5)
tsne_result=df_pbmc.drop(columns="cell_type")
tsne_array=tnse.fit_transform(tsne_result)
df_tsne=pd.DataFrame(tsne_array, columns=["TSNE1","TSNE2"],index=tsne_result.index)
df_tsne=pd.concat([df_tsne,cell_type], axis=1)

# %% [markdown]
# 6. ✅ Task for students: Visualize the results with scatterplot

# %%
# use sns.scatterplot
# your code here
sns.scatterplot(data=df_tsne,x="TSNE1",y="TSNE2",hue="cell_type")
plt.title("TSNE")
plt.xlabel("TSNE1")
plt.ylabel("TSNE2")
plt.show()

# %% [markdown]
# 7. ✅ Task for students: Compare the PCA and t-SNE plots. What patterns do you observe?

# %%
#  Replace the text below with your answer
answer_q7 = """ 
Your answer
"""

# %% [markdown]
# 8. ✅ Task for students: Visualize the cell types on the tSNE embeddings

# %%
# use sns.scatterplot and leverage the hue option
# your code here

# %% [markdown]
#  9. ✅ Task for students: Try changing the perplexity in t-SNE (e.g., 2, 10, 50, 500).

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/miniconda3/envs/DataMining/lib/python3.9/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:173, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), 0)' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[195], line 8
#       1 fig, axs = plt.subplots(1, 4, figsize=(20, 5))
#       3 for i, perplexity in enumerate([2, 10, 50, 500]):
#       4
#       5
#       6     # Your code here
# ----> 8     sns.scatterplot(x=df_tsne[:, 0], y=df_tsne[:, 1], s=10, ax=axs[i], legend=False)
#       9     axs[i].set_title(f"Perplexity={perplexity}")
#      10     axs[i].set_xlabel("t-SNE 1")
#
# File ~/miniconda3/envs/DataMining/lib/python3.9/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~/miniconda3/envs/DataMining/lib/python3.9/site-packages/pandas/core/indexes/base.py:3824, in Index.get_loc(self, key)
#    3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
# -> 3824     self._check_indexing_error(key)
#    3825     raise
#
# File ~/miniconda3/envs/DataMining/lib/python3.9/site-packages/pandas/core/indexes/base.py:6072, in Index._check_indexing_error(self, key)
#    6068 def _check_indexing_error(self, key):
#    6069     if not is_scalar(key):
#    6070         # if key is not a scalar, directly raise an error (the code below
#    6071         # would convert to numpy arrays and raise later any way) - GH29926
# -> 6072         raise InvalidIndexError(key)
#
# InvalidIndexError: (slice(None, None, None), 0)

# %% [markdown]
#  10. ✅ Task for students: What happens to the result (answer below)?

# %%
# Replace the text below with your answer
answer_q10 = """ 
The higher the perplexity is, the more disperse each cell is and the more it is related to different cells, that is why we need to
find a lower perplexity, a better one to dfieerentiate each cell perfectly
"""

# %% [markdown]
# 11. ✅ Task for students: code a loop to run tSNE for three different random seeds, say [1, 42, 99].  For all runs, set preplexity too 30 and limit the maximum number of iterations to 500 and init="random".

# %%
fig, axs = plt.subplots(1, 3, figsize=(18, 5))

for i, seed in enumerate([1, 42, 99]):
   
    # Your code here
    
    sns.scatterplot(x=X_tsne[:, 0], y=X_tsne[:, 1], s=10, ax=axs[i], legend=False)
    axs[i].set_title(f"t-SNE with seed={seed}")
    axs[i].set_xlabel("t-SNE 1")
    axs[i].set_ylabel("t-SNE 2")

plt.tight_layout()
plt.show()

# %% [markdown]
# 12. ✅ Task for students: Why do we have different results after changing the random seed?

# %%
# Replace the text below with your answer
answer_q12 = """ 
Your answer
"""

# %% [markdown]
# 13. ✅ Task for students: Try applying t-SNE directly on `X_scaled` (without PCA). How does the result change, compare visually with the results on X_pca_50?

# %%
# Use a scatter plot to visualize the tSNE on the scaled data vs. PCA-reduced data
fig, axs = plt.subplots(1, 2, figsize=(10, 5))

# apply t-SNE on PCA-reduced data
# apply t-SNE on raw scaled (full) data
# Plot PCA-based t-SNE
# Plot scaled-data t-SNE

# Your code here

# %% [markdown]
# 14. ✅ Task for students: why did using PCA before t-SNE help? or Why is PCA commonly applied before t-SNE on high-dimensional data?

# %%
# Replace the text below with your answer
answer_q14 = """ 
To reduce the number of columns tsne needs to resolve and also reduce compiling time
"""
